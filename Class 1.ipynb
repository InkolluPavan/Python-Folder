# %% [markdown]
# ## History of python
#  - Python is invented by Gudio Van Russom
#  - Python is older than java
#  - The name Python has came from a comedy show named "Monty Python's" Flying Circus

# %%
# Lets Print welcome to unicus learning's data science program
print("Welcome to Unicus learning's data science program")
# Out:
# Welcome to Unicus learning's data science program

# %%
# Create A Varibale and name it 'Name'
Name ='Inkollu Venkata Pavan'
print(Name)
# Out:
# Inkollu Venkata Pavan

# %%
print("My Name is:",Name)
# Out:
# My Name is: Inkollu Venkata Pavan

# %%
#Assign your age to a variable and print it
Age =22
print("My Name is ",Name +" and "+ "My Age is ",Age)
# Out:
# My Name is  Inkollu Venkata Pavan and My Age is  22

# %%
# using the varibale age and print your age after ten years
print("My Name is ",Name +" and "+ "My Age After 10 years is ",Age+10)
# Out:
# My Name is  Inkollu Venkata Pavan and My Age After 10 years is  32

# %%
#Create two variables first name and last name 
# and use those two varibales to find full name
First_name = "Inkollu Venkata"
Second_name = "Pavan"
print("My Full name is:",First_name+" "+Second_name)
# Out:
# My Full name is: Inkollu Venkata Pavan

# %%
#Create two numeric varibales 'a' and 'b'
#and perform all arthimatic operations
a=10
b=2
print("The value of a is :",a,"The value of b is ",b)
print("Addition of a and b :",a+b)
print("Subtraction of a and b :",a-b)
print("Multiplication of a and b :",a*b)
print("a raised power of b is : ",a**b)
print("modulus of a and b :",a%b)
print("Division of a and b :",a/b)
# Out:
# The value of a is : 10 The value of b is  2
# Addition of a and b : 12
# Subtraction of a and b : 8
# Multiplication of a and b : 20
# a raised power of b is :  100
# modulus of a and b : 0
# Division of a and b : 5.0

# %%
#Giving Dynamic input 
a=int(input("Enter the value of a : "))
b=int(input("Enter the value of b : "))
print("The value of a is :",a,"The value of b is ",b)
print("Addition of a and b :",a+b)
print("Subtraction of a and b :",a-b)
print("Multiplication of a and b :",a*b)
print("a raised power of b is : ",a**b)
print("modulus of a and b :",a%b)
print("Division of a and b :",a/b)
# Out:
# Enter the value of a : 10
# Enter the value of b : 2
# The value of a is : 10 The value of b is  2
# Addition of a and b : 12
# Subtraction of a and b : 8
# Multiplication of a and b : 20
# a raised power of b is :  100
# modulus of a and b : 0
# Division of a and b : 5.0

# %%
#Giving Dynamic Inputs 
#Create  two dynamic varibales (Savings and Expendriture) find total earningd
Savings =int(input("Enter the Saving of this month : "))
Expenditure =int(input("Enter the Expedniture of this month : "))
print("Total earnings of this month is :",Savings+Expenditure)
# Out:
# Enter the Saving of this month : 15000
# Enter the Expedniture of this month : 5000
# Total earnings of this month is : 20000
