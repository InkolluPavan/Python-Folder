# %%
#Why do we need computers? Efficiency(Faster), accuracy
#Programming languges = Translators
#C, Java, Python, C++, Rust


#Python => ADVANTAGES => Easy to understand, Opensource, Portable, Interpreted, Inbuilt modules, Python
#Compiled lang and Interpreted

#Disadvantages => Slower, Multithreading 

#Compiled lang => faster, not portable
#Interpreted lang => Slower, portable
#Python is a hybrid language 


#Python => Programming paradigms => 


#Datatypes
#Operators => 
#Variables

# %%
#Operators (symbols) and Operands
# 123 + 345
# 123 - 456
# 124 * 456
# 5 / 2
# 5 % 2
# 5 // 2

# 2 * 3
# 3 * 2
# 2 ** 3
# 3 ** 2


#Variable 
n1 = 1871
n2 = 0


# print(n2 / n1)
print(n1 // n2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 21
#      17 n2 = 0
#      20 # print(n2 / n1)
# ---> 21 print(n1 % n2)
#
# ZeroDivisionError: integer modulo by zero

# %%
#Assignment operators => Assign values to a variable
#=, +=, -=, *=, /=, %=, //=
#Relational operators


num1 = 5 #Assignment =
num1 = 10 #Reassignment =


num1 = num1 + 10 #num1 = 20
amazon_order_quantity = 10
amazon_order_quantity = amazon_order_quantity + 20
amazon_order_quantity += 20



amazon_order_quantity *= 20
#amazon_order_quantity = amazon_order_quantity * 20



print(num1)
# Out:
# 20

# %%
num2 = 55
num1 = 2

num2 %= num1
#num2 = num2 % num1
print(num2)
# Out:
# 1

# %%
#num1 /= 0
#num1 = num1 / 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       1 #num1 /= 0
#       2 #num1 = num1 / 0
# ----> 6 print(num3)
#
# NameError: name 'num3' is not defined

# %%
num3 += 10
#num3 = num3 + 10

# %%
#Relational operators

#==, >=, <=, !=, >, <



num1 = 5

print(num1 == 10)
num1 = 10
print(10 >= 10)
print('23' == 23)



#Data = 23
#Datatypes 
#Numeric => Int, float, complex, boolean
#Sequence => List, tuple, string, range
#Mapping => Dict
#Set
#None




#Int => 245, -32, 0
#float => 5.5, 6.1, -32.0 #+, -,


num1 = 5.5
num2 = 3.2

num1 + num2


#Complex = 


# m + ni
# 2 + 3i

img1 = 2 + 3j
img2 = 8 - 5j
